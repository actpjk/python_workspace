# %% [markdown]
# # 통합파일 분석 및 시각화

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import re
import pandas as pd
import time
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
import OpenDartReader
import os
import seaborn as sns
import sys

# %%
sys.maxsize
set_matplotlib_formats('retina')

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus = False)

pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_columns = 200
pd.options.display.max_rows = 200

# %% [markdown]
# ## 통합 파일 불러오기

# %%
search_df_nm = '반기보고서_선택기간'

data_list = os.listdir()

match_list = list()

for df_nm in data_list:
    if search_df_nm in df_nm:
        match_list.append(df_nm)
        
match_list
# Out:
# ['삼성생명_반기보고서_선택기간5_통합파일.csv', '한화생명_반기보고서_선택기간5_통합파일.csv']

# %%
df_list = list()

for i, file_nm in enumerate(match_list):
    df = pd.read_csv('./{}'.format(file_nm), encoding='utf-8-sig')
    df = df.drop(['Unnamed: 0', '보고기간'], axis = 1)
    df = df.rename(columns={'index':'보고기간'})
    df_list.append(df)

# %%
df_s = df_list[0]
df_h = df_list[1]

# %%
df_s.stack()
df_h.stack()
# Out:
# 0  회사명                               한화생명
#    보고기간                           2016.06
#    1) 매도가능금융자산평가손익                1046675
#    1) 유형자산재평가이익                      7006
#    2) 관계기업의 기타포괄손익지분               -64707
#                                    ...
# 4  특별계정지급수수료                        29212
#    파생상품평가 및 거래손실                  1521660
#    파생상품평가 및 거래이익                   296218
#    후속적으로 당기손익으로 재분류될 수 있는 포괄손익          0
#    Unnamed: 52                          0
# Length: 260, dtype: object

# %%
gs = df_s.groupby(['회사명','보고기간']).mean()

# %%
gh = df_h.groupby(['회사명','보고기간']).mean()

# %%
gs_t = gs.T
gh_t = gh.T

# %% [markdown]
# ## join 으로 병합

# %%
df = gs_t.join(gh_t)

# %%
df = df.T.fillna(0)

# %%
df = df[df != 0]

# %%
df
# Out:
#               관계기업의 기타포괄손익지분  기본주당이익     기타영업비용    기타영업수익  \
# 회사명  보고기간
# 삼성생명 2016.06         9126.00 8690.00  855893.00  94245.00
#      2017.06         3168.00 5272.00 1448467.00 147687.00
#      2018.06         9170.00 8052.00 1622828.00 116167.00
#      2019.06         8988.00 4213.00 1323165.00 313344.00
#      2020.06         6588.00 3779.00 1276346.00 264171.00
# 한화생명 2016.06             nan     nan        nan       nan
#      2017.06             nan     nan        nan       nan
#      2018.06             nan     nan        nan       nan
#      2019.06             nan     nan        nan       nan
#      2020.06             nan     nan        nan       nan
#
#               당기손익으로 재분류되지 않는 포괄손익  당기손익인식금융자산관련손실  당기손익인식금융자산관련이익    당기연결순이익  \
# 회사명  보고기간
# 삼성생명 2016.06             -13802.00       179581.00       216731.00 1620892.00
#      2017.06                213.00       179718.00       272991.00        nan
#      2018.06              -2397.00       240423.00       186422.00        nan
#      2019.06                   nan       302728.00       475889.00        nan
#      2020.06                   nan       723402.00      1062924.00        nan
# 한화생명 2016.06               7077.00             nan             nan        nan
#      2017.06              14738.00             nan             nan        nan
#      2018.06               4167.00             nan             nan        nan
#      2019.06               2757.00             nan             nan        nan
#      2020.06               1925.00             nan             nan        nan
#
#               당기연결순이익의 귀속  당기연결총포괄손익  당기연결총포괄손익의 귀속  대출채권및기타수취채권관련손실  \
# 회사명  보고기간
# 삼성생명 2016.06   1620892.00 4794702.00     4794702.00        149564.00
#      2017.06          nan        nan            nan        129889.00
#      2018.06          nan        nan            nan        181988.00
#      2020.06  797639.00  50547.00                          nan 3779.00
# 한화생명 2016.06  459268.00       nan                   1023214.00     nan
#      2017.06  504779.00       nan                    224046.00     nan
#      2018.06  601826.00       nan                   -213559.00     nan
#      2019.06  475807.00       nan                          nan     nan
#      2020.06  507108.00       nan                          nan     nan

# %%
df = df.reset_index()

# %%
df
# Out:
#     회사명    보고기간  관계기업의 기타포괄손익지분  기본주당이익     기타영업비용    기타영업수익  \
# 0  삼성생명 2016.06         9126.00 8690.00  855893.00  94245.00
# 1  삼성생명 2017.06         3168.00 5272.00 1448467.00 147687.00
# 2  삼성생명 2018.06         9170.00 8052.00 1622828.00 116167.00
# 3  삼성생명 2019.06         8988.00 4213.00 1323165.00 313344.00
# 4  삼성생명 2020.06         6588.00 3779.00 1276346.00 264171.00
# 5  한화생명 2016.06             nan     nan        nan       nan
# 6  한화생명 2017.06             nan     nan        nan       nan
# 7  한화생명 2018.06             nan     nan        nan       nan
# 8  한화생명 2019.06             nan     nan        nan       nan
# 9  한화생명 2020.06             nan     nan        nan       nan
#
#    당기손익으로 재분류되지 않는 포괄손익  당기손익인식금융자산관련손실  당기손익인식금융자산관련이익    당기연결순이익  \
# 0             -13802.00       179581.00       216731.00 1620892.00
# 1                213.00       179718.00       272991.00        nan
# 2              -2397.00       240423.00       186422.00        nan
# 3                   nan       302728.00       475889.00        nan
# 4                   nan       723402.00      1062924.00        nan
# 5               7077.00             nan             nan        nan
# 6              14738.00             nan             nan        nan
# 7               4167.00             nan             nan        nan
# 8               2757.00             nan             nan        nan
# 9               1925.00             nan             nan        nan
#
#    당기연결순이익의 귀속  당기연결총포괄손익  당기연결총포괄손익의 귀속  대출채권및기타수취채권관련손실  대출채권및기타수취채권관련이익  \
# 0   1620892.00 4794702.00     4794702.00        149564.00              nan
# 1          nan        nan            nan        129889.00              nan
# 2          nan        nan            nan        181988.00              nan
# 3          nan        nan            nan        214226.00              nan
# 4          nan        nan            nan        213223.00              nan
# 5          nan        nan            nan              nan              nan
# 6          nan        nan            nan              nan              nan
# 7          nan        nan            nan              nan              nan
# 8          nan        nan            nan              nan              nan
# 9          nan        nan            nan              nan              nan
#
#        리스수익  만기보유금융자산평가손익  매도가능금융자산관련손실  매도가능금융자산관련이익  매도가능금융자산평가손익     배당금수익  \
# 0 137481.00       -152.00      21039.00      57931.00    3229880.00 362919.00
# 1 134734.00        102.00       2055.00      66642.00    2767311.00 539890.00
# 2 171498.00        -16.00       5794.00    1220216.00   -2416129.00 646013.00
# 3 178864.00           nan      31459.00     121911.00    4733241.00 604232.00
# 4 147463.00           nan     139906.00     398839.00    -150419.00 544292.00
# 5       nan           nan           nan           nan           nan       nan
# 6       nan           nan           nan           nan           nan       nan
# 7       nan           nan           nan           nan           nan       nan
# 8       nan           nan           nan           nan           nan       nan
# 9       nan           nan           nan           nan           nan       nan
#
#       법인세비용  법인세비용차감전연결순이익  법인세비용차감후기타포괄손익      보험료수익    비지배지분        사업비  \
# 0 337451.00     1958343.00      3173810.00 8377590.00 51341.00  732578.00
# 1 323192.00     1324037.00      2804258.00 8510477.00 54118.00  761215.00
# 2 530678.00     2020422.00     -2245505.00 8050874.00 43805.00 1106063.00
# 3 258400.00     1052433.00      4876889.00 8057682.00 37427.00 1121236.00
# 7  57459.00 5587905.00        nan               nan        nan         nan
# 8  73188.00 5764440.00        nan               nan        nan         nan
# 9  71600.00 6229515.00        nan               nan        nan         nan
#
#      특별계정비용    특별계정수익  특별계정수입수수료  해외사업환산손익  후속적으로 당기손익으로 재분류될 수 있는 포괄손익  \
# 0 208951.00 208951.00  703989.00 -43565.00                   3187612.00
# 1 228538.00 228538.00  767358.00  41249.00                   2804471.00
# 2 258427.00 258427.00  822137.00  51123.00                  -2243108.00
# 3 271521.00 271521.00  824846.00  56568.00                          nan
# 4 403214.00 403214.00  797639.00  50547.00                          nan
# 5  71330.00  71330.00  459268.00       nan                   1023214.00
# 6 149901.00 151256.00  504779.00       nan                    224046.00
# 7 106907.00 108055.00  601826.00       nan                   -213559.00
# 8 121731.00 123253.00  475807.00       nan                          nan
# 9  98064.00  98064.00  507108.00       nan                          nan
#
#    희석주당이익
# 0 8690.00
# 1 5272.00
# 2 8052.00
# 3 4213.00
# 4 3779.00
# 5     nan
# 6     nan
# 7     nan
# 8     nan
# 9     nan

# %%
p = df.pivot_table(index = '보고기간', columns = '회사명', values = ['영업이익','보험료수익','법인세비용','지급보험금'])

# %% [markdown]
# ## 시각화

# %%
plt.figure(figsize=(13, 7))
sns.barplot(data=df, x="보고기간", y="영업이익", hue="회사명").set_title('회사별 영업이익 비교')
# Out:
# Text(0.5, 1.0, '회사별 영업이익 비교')

# %%
plt.figure(figsize=(13, 7))
sns.barplot(data=df, x="보고기간", y="지급보험금", hue="회사명").set_title('회사별 지급보험금 비교')
# Out:
# Text(0.5, 1.0, '회사별 지급보험금 비교')

# %%
plt.figure(figsize=(13, 10))
sns.lmplot(data=df, x="지급보험금", y="보험료수익", hue="회사명", col="회사명", col_wrap=2,  x_jitter=.1)

# %%
plt.figure(figsize=(13, 7))
sns.regplot(data=df, x="영업이익", y="지급보험금", x_jitter=.1).set_title('영업이익과 지급보험금 회귀분석')
# Out:
# Text(0.5, 1.0, '영업이익과 지급보험금 회귀분석')

# %%
p = p.stack()

# %%
p = p.reset_index()

# %%
ps = p[p['회사명'] == '삼성생명']
ph = p[p['회사명'] == '한화생명']

# %%
ps['보고기간'] = ps['보고기간'].astype(str)
ph['보고기간'] = ph['보고기간'].astype(str)
# Out:
# <ipython-input-89-ee0a0f05508a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ps['보고기간'] = ps['보고기간'].astype(str)
# <ipython-input-89-ee0a0f05508a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ph['보고기간'] = ph['보고기간'].astype(str)

# %%
ph.dtypes
# Out:
# 보고기간      object
# 회사명       object
# 법인세비용    float64
# 보험료수익    float64
# 영업이익     float64
# 지급보험금    float64
# dtype: object

# %%
plt.figure(figsize=(13, 7))
corr = ph.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
sns.heatmap(corr, annot=True, cmap="Blues", mask=mask).set_title('한화생명 포괄손익계산서 상관관계 분석')
# Out:
# Text(0.5, 1.0, '한화생명 포괄손익계산서 상관관계 분석')

# %%
plt.figure(figsize=(13, 7))
corr = ps.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
sns.heatmap(corr, annot=True, cmap="Blues", mask=mask).set_title('삼성생명 포괄손익계산서 상관관계 분석')
# Out:
# Text(0.5, 1.0, '삼성생명 포괄손익계산서 상관관계 분석')
